# %% [markdown]
# <a href="https://colab.research.google.com/github/thecodemaster152/Brief-guide-to-tensor-flow/blob/main/02_neural_network_classification_in_TF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##02. Neural Network Classification with TensorFlow

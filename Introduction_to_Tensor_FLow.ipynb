# %% [markdown]
# <a href="https://colab.research.google.com/github/thecodemaster152/Brief-guide-to-tensor-flow/blob/main/Introduction_to_Tensor_FLow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Question 1: What is Tesnor flow?
#
#     TensorFlow is an open-source machine learning and deep learning framework developed by Google.
#
#     It is mainly used to build, train, and deploy AI models such as:
#
#     Image classification
#
#     Speech recognition
#
#     Natural language processing
#
#     Recommendation systems
#
#     Deep neural networks
#
# In simple terms:
#
# TensorFlow is a library that helps computers learn patterns from data.

# %% [markdown]
# ##Question 2: Why the Name Tensor flow?
#
#     A tensor is just a multi-dimensional array of numbers.
#
# | Data Type                         | Tensor Dimension |
# | --------------------------------- | ---------------- |
# | Single number                     | 0-D tensor       |
# | List of numbers                   | 1-D tensor       |
# | Matrix                            | 2-D tensor       |
# | Image (height × width × channels) | 3-D tensor       |
# | Video dataset                     | 4-D tensor       |
#
#
#     A tensor flow through these operations hence the name TensorFlow
#
#     Input Data → Neural Network Layers → Loss Calculation → Optimization → Predictions

# %% [markdown]
# ##Question 3: Why do we need Tensor flow?
#
#     Te real purpose is:
#
#     To make building large-scale AI systems practical.
#
#     It provides:
#
#     Efficient math operations
#
#     Automatic differentiation
#
#     Neural network tools
#
#     GPU acceleration
#
#     Deployment infrastructure
#
#
# TensorFlow automatically handles:
#
# | Hard Task         | TensorFlow Does It |
# | ----------------- | ------------------ |
# | Matrix operations | Yes                |
# | Gradients         | Yes                |
# | Backpropagation   | Yes                |
# | GPU computation   | Yes                |
# | Training loops    | Yes                |

# %% [markdown]
# How does Tensor Flow works?

# %%
pip install tensor
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.3/50.3 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 343.4/343.4 kB 11.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 56.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.9/264.9 kB 18.7 MB/s eta 0:00:00
# ...
#   Created wheel for tensor: filename=tensor-0.3.6-py3-none-any.whl size=71551 sha256=74bdc5386d63e3013860bf576d401b4904a0193169efe3afe9f47b355e85e0ef
#   Stored in directory: /root/.cache/pip/wheels/e4/bf/a5/4555f996fe09316f1bd2112d902c4d219d7dda5f8632cd2bc3
# Successfully built tensor
# ...
